# %% [markdown]
# # REMIX-FND — T4 benchmark (text classifier)
#
# 1. **Runtime → Change runtime type → GPU (T4)**
# 2. Run cells in order.
# 3. If the repo is **private**, use a [GitHub token](https://github.com/settings/tokens) in the clone cell or upload a zip instead.

# %%
# Default: public clone (if private, use token: git clone https://TOKEN@github.com/USER/Remix-fnd.git)
# !git clone https://github.com/PriyadarshanKhadtale/Remix-fnd.git
# %cd Remix-fnd

# Alternative: Google Drive
# from google.colab import drive
# drive.mount('/content/drive')
# %cd /content/drive/MyDrive/path/to/Remix-fnd

# %%
# !pip install -q -r training/requirements-train.txt
import torch
print('cuda:', torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else None)

# %%
# Full FakeNewsNet JSON benchmark: train 3 epochs + full test eval + JSON metrics
# !python3 training/scripts/run_benchmarks.py --device auto --epochs 3 --train_batch_size 32 --eval_batch_size 64

# %%
# Show summary (also on disk: benchmark_summary.json, benchmark_eval_metrics.json)
# !cat benchmark_summary.json

# %%
from google.colab import files
files.download('benchmark_summary.json')
files.download('benchmark_eval_metrics.json')
